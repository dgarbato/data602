# %% [markdown]
# Q1. What will the following code display?

# %%
numbers = [1, 2, 3, 4, 5]
print(numbers[1:-5])
# Out:
# []

# %% [markdown]
# An empty list
#
# Can you debug and fix the output? The code should return the entire list

# %%
print(numbers[:])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Q2. Design a program that asks the user to enter a store’s sales for each day of the
# week. The amounts should be stored in a list. Use a loop to calculate the total sales for
# the week and display the result.

# %%
sales = []

days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]

# Collect sales for each day
for day in days:
    amount = float(input(f"Enter sales for {day}: "))
    sales.append(amount)

# Calculate total sales
total = 0
for amount in sales:
    total = total + amount

# Display result
print("Total sales for the week:", total)
# Out:
# Enter sales for Sunday:  100
# Enter sales for Monday:  900
# Enter sales for Tuesday:  700
# Enter sales for Wednesday:  600
# Enter sales for Thursday:  500
# Enter sales for Friday:  200
# Enter sales for Saturday:  400
# Total sales for the week: 3400.0

# %% [markdown]
# Q3. Create a list with at least 5 places you’d like to travel to. Make sure the list isn’t in
# alphabetical order
#
#         ● Print your list in its original order.
#         ● Use the sort() function to arrange your list in order and reprint your list.
#         ● Use the sort(reverse=True) and reprint your list.

# %%
travel_spots = ['Tokyo', 'London', 'Rome', 'Alaska', 'Paris' ]
print(travel_spots)
# Out:
# ['Tokyo', 'London', 'Rome', 'Alaska', 'Paris']

# %%
travel_spots.sort() 
print(travel_spots)
# Out:
# ['Alaska', 'London', 'Paris', 'Rome', 'Tokyo']

# %%
travel_spots.sort(reverse = True)
print(travel_spots)
# Out:
# ['Tokyo', 'Rome', 'Paris', 'London', 'Alaska']

# %% [markdown]
# Q4. Write a program that creates a dictionary containing course numbers and the room
# numbers of the rooms where the courses meet. The program should also create a
# dictionary containing course numbers and the names of the instructors that teach each
# course. After that, the program should let the user enter a course number, then it should
# display the course’s room number, instructor, and meeting time.

# %%
# Create a dictionary for course look-up
courses = {
    "data602": {"room": "3004", "instructor": "Schettini", "time": "5:00 PM"},
    "data606": {"room": "4501", "instructor": "Hui", "time": "8:00 PM"},
    "data607": {"room": "6755", "instructor": "Hagstrom", "time": "6:45 PM"}
}
# make sure entry is in lowercase
course = input("Enter course number: ").lower()

if course in courses:
    print("Room:", courses[course]["room"])
    print("Instructor:", courses[course]["instructor"])
    print("Meeting time:", courses[course]["time"])
else:
    print("Course not found.")
# Out:
# Enter course number:  data606
# Room: 4501
# Instructor: Hui
# Meeting time: 8:00 PM

# %% [markdown]
# Q5. Write a program that keeps names and email addresses in a dictionary as
# key-value pairs. The program should then demonstrate the four options:
#
#     ● look up a person’s email address,
#     ● add a new name and email address,
#     ● change an existing email address, and
#     ● delete an existing name and email address.

# %%
name_email_dict = {'Kelly':'kelly459@gmail.com', 'Robert':'robert369@gmail.com', 'Anna':'anna909@gmail.com'}

# %%
name_email_dict['Kelly']
# Out:
# 'kelly459@gmail.com'

# %%
name_email_dict['Walter'] = 'walter134@gmail.com'

# %%
print(name_email_dict)
# Out:
# {'Kelly': 'kelly459@gmail.com', 'Robert': 'robert369@gmail.com', 'Anna': 'anna909@gmail.com', 'Walter': 'walter134@gmail.com'}

# %%
name_email_dict['Robert'] = 'robert345@outlook.com'
print(name_email_dict)
# Out:
# {'Kelly': 'kelly459@gmail.com', 'Robert': 'robert345@outlook.com', 'Anna': 'anna909@gmail.com', 'Walter': 'walter134@gmail.com'}

# %%
del name_email_dict['Robert']
print(name_email_dict)
# Out:
# {'Kelly': 'kelly459@gmail.com', 'Anna': 'anna909@gmail.com', 'Walter': 'walter134@gmail.com'}
